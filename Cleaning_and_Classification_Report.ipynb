# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report

df= pd.DataFrame(pd.read_csv("/content/sentiment_test4000.csv"))

# %%
df.drop(columns=['Unnamed: 4'], inplace= True)

# %%
df
# Out:
#                                                    text  label Response  \
# 0     @user @user what do these '1/2 naked pics' hav...      1        1
# 1     OH: “I had a blue penis while I was this” [pla...      1        1
# 2     @user @user That's coming, but I think the vic...      1        0
# 3     I think I may be finally in with the in crowd ...      2        2
# 4     @user Wow,first Hugo Chavez and now Fidel Cast...      0        0
# ...                                                 ...    ...      ...
# 4633  Catholics, pull yourselves together, show loya...      2      NaN
# 4634  WW3-Part-1-Putin Views-Russia And America-Trum...      1      NaN
# 4635               #ThisIsUs literally warms my heart😭😍      2      NaN
# 4636  I'm a little late to this, but this piece is e...      2        2
# 4637  From a dead stop, Tesla estimates that the Mod...      1        1
#
#                                             Explanation
# 0                                                   NaN
# 1                                                   NaN
# 2     This tweet implies a negative outcome or conse...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4633                                                NaN
# 4634                                                NaN
# 4635                                                NaN
# 4636                                                NaN
# 4637                                                NaN
#
# [4638 rows x 4 columns]

# %%
df['Response'] = df.apply(lambda row: row['label'] if pd.isnull(row['Response']) else row['Response'], axis=1)

# %%
df.Response.value_counts()
# Out:
# Response
# 1                                                                                                                                                                                                                     1408
# 0                                                                                                                                                                                                                      996
# 1                                                                                                                                                                                                                      788
# 2                                                                                                                                                                                                                      573
# 0                                                                                                                                                                                                                      496
# 2                                                                                                                                                                                                                      369
# Mixed                                                                                                                                                                                                                    6
# The use of phrases like "ur $2 trip is now $4" and "#timeisvaluable" suggests annoyance at the perceived unfairness of the situation. The hashtags used also indicate a sense of dissatisfaction with the service.       1
# Working towards accreditation, albeit on half the minimum wage is much better than sitting on your arse bludging of…                                                                                                     1
# Name: count, dtype: int64

# %%
def string_to_int(s):
    try:
        return int(s)
    except ValueError:
        print(f"'{s}' is not a valid integer string.")
        return None

# %%
filtered_df = df[~df['Response'].isin([0, 1, 2])]

# %%
df['Response'].iloc[3262]=0
df['Explanation'].iloc[3262]="The use of phrases like ur"
# Out:
# <ipython-input-10-fadd8c6db324>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Response'].iloc[3262]=0
# <ipython-input-10-fadd8c6db324>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Response'].iloc[3262]=0
# <ipython-input-10-fadd8c6db324>:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Explanation'].iloc[3262]="The use of phrases like ur"
# <ipython-input-10-fadd8c6db324>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Explanation'].iloc[3262]="The use of phrases like ur"

# %%
df['text'].iloc[4477]
# Out:
# 'when u start eating thanksgiving dinner before u say grace & ur grandma catches u'

# %%
df['Response'].iloc[4477]
# Out:
# 'Working towards accreditation, albeit on half the minimum wage is much better than sitting on your arse bludging of…'

# %%
df['Explanation'].iloc[4477]=df['Response'].iloc[4477]
df['Response'].iloc[4477]=1
# Out:
# <ipython-input-13-b1edf3d4e39c>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Explanation'].iloc[4477]=df['Response'].iloc[4477]
# <ipython-input-13-b1edf3d4e39c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Explanation'].iloc[4477]=df['Response'].iloc[4477]
# <ipython-input-13-b1edf3d4e39c>:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Response'].iloc[4477]=1
# <ipython-input-13-b1edf3d4e39c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Response'].iloc[4477]=1

# %%
filtered_df
# Out:
#                                                    text  label Response  \
# 0     @user @user what do these '1/2 naked pics' hav...      1        1
# 1     OH: “I had a blue penis while I was this” [pla...      1        1
# 2     @user @user That's coming, but I think the vic...      1        0
# 3     I think I may be finally in with the in crowd ...      2        2
# 4     @user Wow,first Hugo Chavez and now Fidel Cast...      0        0
# ...                                                 ...    ...      ...
# 4592  @user will provide federal funds to have an ag...      2        1
# 4615  @user To those who think of alt-rightists as N...      0        1
# 4618  #Valentines #Gifts NEW Ted 2 in Jersey 24-Inch...      2        2
# 4636  I'm a little late to this, but this piece is e...      2        2
# 4637  From a dead stop, Tesla estimates that the Mod...      1        1
#
#                                             Explanation
# 0                                                   NaN
# 1                                                   NaN
# 2     This tweet implies a negative outcome or conse...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4592  The tweet describes a policy proposal without ...
# 4615  The tweet is asking a question and seeking inf...
# 4618                                                NaN
# 4636                                                NaN
# 4637                                                NaN
#
# [1661 rows x 4 columns]

# %%
df['Response'][df['Response']=="1"]=1
df['Response'][df['Response']=="1 "]=1
df['Response'][df['Response']=="2"]=2
df['Response'][df['Response']=="0"]=0
df.replace('Mixed', 1, inplace=True)
# Out:
# <ipython-input-15-a0df38a62fd0>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Response'][df['Response']=="1"]=1
# <ipython-input-15-a0df38a62fd0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Response'][df['Response']=="1"]=1
# <ipython-input-15-a0df38a62fd0>:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Response'][df['Response']=="1 "]=1
# <ipython-input-15-a0df38a62fd0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Response'][df['Response']=="1 "]=1
# <ipython-input-15-a0df38a62fd0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Response'][df['Response']=="2"]=2
# <ipython-input-15-a0df38a62fd0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Response'][df['Response']=="2"]=2
# <ipython-input-15-a0df38a62fd0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Response'][df['Response']=="0"]=0
# <ipython-input-15-a0df38a62fd0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Response'][df['Response']=="0"]=0
# <ipython-input-15-a0df38a62fd0>:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace('Mixed', 1, inplace=True)

# %%
df.label.value_counts()
# Out:
# label
# 1    2284
# 0    1443
# 2     911
# Name: count, dtype: int64

# %%
df.Response.value_counts()
# Out:
# Response
# 1    2203
# 0    1493
# 2     942
# Name: count, dtype: int64

# %%
true_labels = df['label'].values
predictions = df['Response'].values
true_labels = true_labels.astype(int)
predictions = predictions.astype(int)

# Compute accuracy
accuracy = accuracy_score(true_labels, predictions)
print(f"Accuracy: {accuracy}")

# Compute multi-class recall, precision, f1-score, etc.
report = classification_report(true_labels, predictions)
print(report)
# Out:
# Accuracy: 0.9594652867615352
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95      1443
#            1       0.98      0.94      0.96      2284
#            2       0.95      0.98      0.96       911
#
#     accuracy                           0.96      4638
#    macro avg       0.95      0.96      0.96      4638
# weighted avg       0.96      0.96      0.96      4638
